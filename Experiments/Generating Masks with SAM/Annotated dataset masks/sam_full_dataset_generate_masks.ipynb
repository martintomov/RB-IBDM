# %% [markdown]
# <a href="https://colab.research.google.com/github/martintmv-git/RB-IBDM/blob/main/Experiments/Generating%20Masks%20with%20SAM/Annotated%20dataset%20masks/sam_full_dataset_generate_masks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # RB-IBDM Image Segmentation
# ### Segment Anything by Meta AI
# ### Generating object masks with SAM for RB-IBDM and saving them in Google Drive

# %% [markdown]
# ## Before starting
#
# Make sure you are connected to a GPU.

# %%
# !nvidia-smi
# Out:
# Thu Mar 28 18:45:03 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   70C    P8              12W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# **NOTE:** To make it easier for us to manage datasets, images and models we create a `HOME` constant.

# %%
import os
HOME = os.getcwd()
print("HOME:", HOME)
# Out:
# HOME: /content

# %% [markdown]
# # Install Segment Anything Model (SAM) and dependencies

# %%
# !pip install -q 'git+https://github.com/facebookresearch/segment-anything.git'
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for segment-anything (setup.py) ... done

# %% [markdown]
# # Download SAM weights

# %%
# !mkdir -p {HOME}/weights
# !wget -q https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth -P {HOME}/weights

# %%
import os

CHECKPOINT_PATH = os.path.join(HOME, "weights", "sam_vit_h_4b8939.pth")
print(CHECKPOINT_PATH, "; exist:", os.path.isfile(CHECKPOINT_PATH))
# Out:
# /content/weights/sam_vit_h_4b8939.pth ; exist: True

# %% [markdown]
# # Download Insect Data

# %%
# !mkdir -p {HOME}/data

import os
from google.colab import drive

drive.mount('/content/drive')

# Dataset of images
dataset_path = '/content/drive/MyDrive/diopsis_tests/images_clean'

# Where the generated masks will be saved
save_path = '/content/drive/MyDrive/diopsis_tests/diopsis_masks_generated'

# Ensure the directory exists
if not os.path.exists(save_path):
    os.makedirs(save_path)
    print(f"Directory created for saving masks: {save_path}")
else:
    print(f"Save directory already exists: {save_path}")

# Counting the number of images in the dataset
num_images = len(os.listdir(dataset_path))
print(f"Number of images read in dataset: {num_images}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Save directory already exists: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated
# Number of images read in dataset: 27649

# %% [markdown]
# # Load Model

# %%
import torch

DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
MODEL_TYPE = "vit_h"

# %%
from segment_anything import sam_model_registry, SamAutomaticMaskGenerator, SamPredictor

sam = sam_model_registry[MODEL_TYPE](checkpoint=CHECKPOINT_PATH).to(device=DEVICE)

# %% [markdown]
# # Automated Mask Generation
#
# To run automatic mask generation, provide a SAM model to the `SamAutomaticMaskGenerator` class. Set the path below to the SAM checkpoint. Running on CUDA and with the default model is recommended.

# %%
mask_generator = SamAutomaticMaskGenerator(sam)

# %% [markdown]
# ### Generate masks with SAM
#
# Creating `processed_images.txt` so if I need to re-run the script after quitting, it will first read the `processed_images.txt` file to determine which images have already been processed.
#
# This approach saves a lot of time and computational resources, especially when working with large datasets or when running processes that have a long execution time, as it prevents reprocessing of images that have already been handled. It's a simple yet effective.

# %%
import cv2
from PIL import Image
import numpy as np

def save_masks_to_drive(masks, save_path, image_name):
    if masks:  # Check if there is at least one mask
        try:
            img = Image.fromarray((masks[0] * 255).astype(np.uint8))  # Use only the first mask
            mask_file_path = os.path.join(save_path, f'mask_{image_name}_0.png')  # Name for the first mask
            img.save(mask_file_path)
            print(f"Successfully saved mask to drive: {mask_file_path}")
            return True
        except Exception as e:
            print(f"Failed saving mask to drive for {image_name}: {e}")
            return False

def process_images_in_batches(dataset_path, save_path, batch_size=100):
    processed_images_file = os.path.join(save_path, "processed_images.txt")
    if os.path.exists(processed_images_file):
        with open(processed_images_file, "r") as file:
            processed_images = set(file.read().splitlines())
    else:
        processed_images = set()

    image_paths = [os.path.join(dataset_path, f) for f in os.listdir(dataset_path) if os.path.isfile(os.path.join(dataset_path, f))]

    for i in range(0, len(image_paths), batch_size):
        batch_paths = image_paths[i:i+batch_size]
        for path in batch_paths:
            image_name = os.path.basename(path).replace('.jpg', '').replace('.png', '')
            if image_name in processed_images:
                print(f"Skipping already processed image: {path}")
                continue  # Skip this image because it has already been processed
                          # as generating masks for the whole dataset takes around 18h

            try:
                print(f"Processing: {path}")
                image_bgr = cv2.imread(path)
                image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)
                sam_result = mask_generator.generate(image_rgb)
                masks = [mask['segmentation'] for mask in sorted(sam_result, key=lambda x: x['area'], reverse=True)]

                if save_masks_to_drive(masks, save_path, image_name):
                    with open(processed_images_file, "a") as file:
                        file.write(f"{image_name}\n")
                    print(f"Successfully processed and saved masks for: {path}")
            except Exception as e:
                print(f"Error processing {path}: {e}")


process_images_in_batches(dataset_path, save_path, batch_size=100)
# Out:
# Streaming output truncated to the last 5000 lines.
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/174_20200716000732_31907.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_174_20200716000732_31907_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/174_20200716000732_31907.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32153.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200809024853_32153_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32153.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/271_20210918015217_31823.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_271_20210918015217_31823_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/271_20210918015217_31823.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32117.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200809024853_32117_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32117.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32129.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200809024853_32129_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32129.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/118_20200827000312_31875.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_118_20200827000312_31875_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/118_20200827000312_31875.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32083.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200809024853_32083_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32083.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32107.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200809024853_32107_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32107.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/118_20200808225026_32024.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_118_20200808225026_32024_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/118_20200808225026_32024.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/174_20200716000732_31924.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_174_20200716000732_31924_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/174_20200716000732_31924.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32084.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200809024853_32084_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32084.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32135.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200809024853_32135_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32135.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32147.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200809024853_32147_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32147.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32116.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200809024853_32116_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32116.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/168_20200716031316_31887.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_168_20200716031316_31887_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/168_20200716031316_31887.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32158.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200809024853_32158_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32158.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32115.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200809024853_32115_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32115.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/118_20200827000312_31876.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_118_20200827000312_31876_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/118_20200827000312_31876.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32124.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200809024853_32124_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32124.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/290_20210725044128_31858.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_290_20210725044128_31858_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/290_20210725044128_31858.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32195.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200809024853_32195_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32195.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/290_20210914113501_32022.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_290_20210914113501_32022_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/290_20210914113501_32022.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32179.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200809024853_32179_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32179.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/174_20200716000732_31915.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_174_20200716000732_31915_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/174_20200716000732_31915.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/126_20200831225138_31820.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_126_20200831225138_31820_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/126_20200831225138_31820.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/174_20200716000732_31957.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_174_20200716000732_31957_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/174_20200716000732_31957.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/118_20200808225026_32027.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_118_20200808225026_32027_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/118_20200808225026_32027.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/174_20200716000732_31909.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_174_20200716000732_31909_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/174_20200716000732_31909.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/174_20200716000732_31893.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_174_20200716000732_31893_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/174_20200716000732_31893.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/174_20200716000732_31959.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_174_20200716000732_31959_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/174_20200716000732_31959.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/174_20200716000732_31911.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_174_20200716000732_31911_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/174_20200716000732_31911.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/105_20200728031738_32256.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_105_20200728031738_32256_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/105_20200728031738_32256.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32088.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200809024853_32088_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32088.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32095.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200809024853_32095_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32095.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/271_20210918015217_31843.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_271_20210918015217_31843_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/271_20210918015217_31843.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32140.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200809024853_32140_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32140.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/174_20200716000732_31904.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_174_20200716000732_31904_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/174_20200716000732_31904.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/290_20210725044128_31853.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_290_20210725044128_31853_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/290_20210725044128_31853.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32167.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200809024853_32167_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32167.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/174_20200716000732_31935.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_174_20200716000732_31935_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/174_20200716000732_31935.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/271_20210913232222_31998.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_271_20210913232222_31998_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/271_20210913232222_31998.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/174_20200716000732_31898.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_174_20200716000732_31898_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/174_20200716000732_31898.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32210.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200809024853_32210_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32210.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32168.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200809024853_32168_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32168.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/118_20200827000312_31863.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_118_20200827000312_31863_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/118_20200827000312_31863.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/174_20200716000732_31901.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_174_20200716000732_31901_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/174_20200716000732_31901.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/174_20200716000732_31962.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_174_20200716000732_31962_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/174_20200716000732_31962.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/174_20200716000732_31921.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_174_20200716000732_31921_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/174_20200716000732_31921.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32191.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200809024853_32191_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32191.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32080.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200809024853_32080_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32080.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/105_20200728031738_32258.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_105_20200728031738_32258_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/105_20200728031738_32258.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/118_20200808225026_32023.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_118_20200808225026_32023_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/118_20200808225026_32023.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/174_20200716000732_31929.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_174_20200716000732_31929_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/174_20200716000732_31929.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/174_20200716000732_31927.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_174_20200716000732_31927_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/174_20200716000732_31927.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32160.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200809024853_32160_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32160.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/174_20200716000732_31914.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_174_20200716000732_31914_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/174_20200716000732_31914.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32085.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200809024853_32085_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32085.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32126.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200809024853_32126_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32126.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32109.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200809024853_32109_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32109.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/217_20210723025610_32004.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_217_20210723025610_32004_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/217_20210723025610_32004.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/174_20200716000732_31948.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_174_20200716000732_31948_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/174_20200716000732_31948.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/118_20200808225026_32026.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_118_20200808225026_32026_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/118_20200808225026_32026.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/271_20210918015217_31839.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_271_20210918015217_31839_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/271_20210918015217_31839.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/174_20200716000732_31944.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_174_20200716000732_31944_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/174_20200716000732_31944.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32114.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200809024853_32114_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32114.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32098.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200809024853_32098_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32098.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/118_20200808225026_32031.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_118_20200808225026_32031_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/118_20200808225026_32031.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32074.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200809024853_32074_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32074.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32192.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200809024853_32192_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32192.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32155.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200809024853_32155_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32155.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200809024853_32121.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200809024853_
jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_185_20200812235937_30786_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/185_20200812235937_30786.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/172_20200819004826_30685.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_172_20200819004826_30685_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/172_20200819004826_30685.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200812012227_31600.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200812012227_31600_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200812012227_31600.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/126_20200810024256_30958.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_126_20200810024256_30958_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/126_20200810024256_30958.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/126_20200810024256_30969.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_126_20200810024256_30969_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/126_20200810024256_30969.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/126_20200810024256_30957.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_126_20200810024256_30957_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/126_20200810024256_30957.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/126_20200810024256_30955.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_126_20200810024256_30955_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/126_20200810024256_30955.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200812012227_31599.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200812012227_31599_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200812012227_31599.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/126_20200810024256_30992.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_126_20200810024256_30992_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/126_20200810024256_30992.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200812012227_31616.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200812012227_31616_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200812012227_31616.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200812012227_31609.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200812012227_31609_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200812012227_31609.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200812012227_31611.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200812012227_31611_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200812012227_31611.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/126_20200810024256_30959.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_126_20200810024256_30959_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/126_20200810024256_30959.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200812012227_31605.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200812012227_31605_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200812012227_31605.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/126_20200810024256_30964.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_126_20200810024256_30964_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/126_20200810024256_30964.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200812012227_31585.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200812012227_31585_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200812012227_31585.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/290_20210826070513_30942.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_290_20210826070513_30942_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/290_20210826070513_30942.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/296_20210819020248_30945.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_296_20210819020248_30945_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/296_20210819020248_30945.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/126_20200810024256_30966.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_126_20200810024256_30966_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/126_20200810024256_30966.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200812012227_31604.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200812012227_31604_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200812012227_31604.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/126_20200810024256_30995.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_126_20200810024256_30995_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/126_20200810024256_30995.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200812012227_31619.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200812012227_31619_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200812012227_31619.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/126_20200810024256_30990.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_126_20200810024256_30990_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/126_20200810024256_30990.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200812012227_31593.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200812012227_31593_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200812012227_31593.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200812012227_31607.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200812012227_31607_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200812012227_31607.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200812012227_31621.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_196_20200812012227_31621_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/196_20200812012227_31621.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/292_20210830060514_30915.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-2a1b5272568b> in <cell line: 51>()
#      49
#      50
# ---> 51 process_images_in_batches(dataset_path, save_path, batch_size=100)
#
# <ipython-input-13-2a1b5272568b> in process_images_in_batches(dataset_path, save_path, batch_size)
#      38                 image_bgr = cv2.imread(path)
#      39                 image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)
# ---> 40                 sam_result = mask_generator.generate(image_rgb)
#      41                 masks = [mask['segmentation'] for mask in sorted(sam_result, key=lambda x: x['area'], reverse=True)]
#      42
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     113     def decorate_context(*args, **kwargs):
#     114         with ctx_factory():
# --> 115             return func(*args, **kwargs)
#     116
#     117     return decorate_context
#
# /usr/local/lib/python3.10/dist-packages/segment_anything/automatic_mask_generator.py in generate(self, image)
#     161
#     162         # Generate masks
# --> 163         mask_data = self._generate_masks(image)
#     164
#     165         # Filter small disconnected regions and holes in masks
#
# /usr/local/lib/python3.10/dist-packages/segment_anything/automatic_mask_generator.py in _generate_masks(self, image)
#     204         data = MaskData()
#     205         for crop_box, layer_idx in zip(crop_boxes, layer_idxs):
# --> 206             crop_data = self._process_crop(image, crop_box, layer_idx, orig_size)
#     207             data.cat(crop_data)
#     208
#
# /usr/local/lib/python3.10/dist-packages/segment_anything/automatic_mask_generator.py in _process_crop(self, image, crop_box, crop_layer_idx, orig_size)
#     243         data = MaskData()
#     244         for (points,) in batch_iterator(self.points_per_batch, points_for_image):
# --> 245             batch_data = self._process_batch(points, cropped_im_size, crop_box, orig_size)
#     246             data.cat(batch_data)
#     247             del batch_data
#
# /usr/local/lib/python3.10/dist-packages/segment_anything/automatic_mask_generator.py in _process_batch(self, points, im_size, crop_box, orig_size)
#     295         if self.pred_iou_thresh > 0.0:
#     296             keep_mask = data["iou_preds"] > self.pred_iou_thresh
# --> 297             data.filter(keep_mask)
#     298
#     299         # Calculate stability score
#
# /usr/local/lib/python3.10/dist-packages/segment_anything/utils/amg.py in filter(self, keep)
#      47                 self._stats[k] = None
#      48             elif isinstance(v, torch.Tensor):
# ---> 49                 self._stats[k] = v[torch.as_tensor(keep, device=v.device)]
#      50             elif isinstance(v, np.ndarray):
#      51                 self._stats[k] = v[keep.detach().cpu().numpy()]
#
# KeyboardInterrupt:

# %% [markdown]
# ## Checking if the number of images in the dataset match the number of processed images

# %%
num_images = len(os.listdir(dataset_path))
print(f"Number of images read in dataset: {num_images}")

# ------------------------------------------------------

num_images = len(os.listdir(save_path))
print(f"Number of images read in processed images: {num_images}")
# Out:
# Number of images read in dataset: 27649
# Number of images read in processed images: 10896
