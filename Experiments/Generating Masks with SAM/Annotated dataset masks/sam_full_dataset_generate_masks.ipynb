# %% [markdown]
# <a href="https://colab.research.google.com/github/martintmv-git/RB-IBDM/blob/main/Experiments/Generating%20Masks%20with%20SAM/Annotated%20dataset%20masks/sam_full_dataset_generate_masks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # RB-IBDM Image Segmentation
# ### Segment Anything by Meta AI
# ### Generating object masks with SAM for RB-IBDM and saving them in Google Drive

# %% [markdown]
# ## Before starting
#
# Make sure you are connected to a GPU.

# %%
# !nvidia-smi
# Out:
# Sat Mar 30 17:48:31 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   67C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# **NOTE:** To make it easier for us to manage datasets, images and models we create a `HOME` constant.

# %%
import os
HOME = os.getcwd()
print("HOME:", HOME)
# Out:
# HOME: /content

# %% [markdown]
# # Install Segment Anything Model (SAM) and dependencies

# %%
# !pip install -q 'git+https://github.com/facebookresearch/segment-anything.git'
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for segment-anything (setup.py) ... done

# %% [markdown]
# # Download SAM weights

# %%
# !mkdir -p {HOME}/weights
# !wget -q https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth -P {HOME}/weights

# %%
import os

CHECKPOINT_PATH = os.path.join(HOME, "weights", "sam_vit_h_4b8939.pth")
print(CHECKPOINT_PATH, "; exist:", os.path.isfile(CHECKPOINT_PATH))
# Out:
# /content/weights/sam_vit_h_4b8939.pth ; exist: True

# %% [markdown]
# # Download Insect Data

# %%
# !mkdir -p {HOME}/data

import os
from google.colab import drive

drive.mount('/content/drive')

# Dataset of images
dataset_path = '/content/drive/MyDrive/diopsis_tests/images_clean'

# Where the generated masks will be saved
save_path = '/content/drive/MyDrive/diopsis_tests/diopsis_masks_generated'

# Ensure the directory exists
if not os.path.exists(save_path):
    os.makedirs(save_path)
    print(f"Directory created for saving masks: {save_path}")
else:
    print(f"Save directory already exists: {save_path}")

# Counting the number of images in the dataset
num_images = len(os.listdir(dataset_path))
print(f"Number of images read in dataset: {num_images}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Save directory already exists: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated
# Number of images read in dataset: 27649

# %% [markdown]
# # Load Model

# %%
import torch

DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
MODEL_TYPE = "vit_h"

# %%
from segment_anything import sam_model_registry, SamAutomaticMaskGenerator, SamPredictor

sam = sam_model_registry[MODEL_TYPE](checkpoint=CHECKPOINT_PATH).to(device=DEVICE)

# %% [markdown]
# # Automated Mask Generation
#
# To run automatic mask generation, provide a SAM model to the `SamAutomaticMaskGenerator` class. Set the path below to the SAM checkpoint. Running on CUDA and with the default model is recommended.

# %%
mask_generator = SamAutomaticMaskGenerator(sam)

# %% [markdown]
# ### Generate masks with SAM
#
# Creating `processed_images.txt` so if I need to re-run the script after quitting, it will first read the `processed_images.txt` file to determine which images have already been processed.
#
# This approach saves a lot of time and computational resources, especially when working with large datasets or when running processes that have a long execution time, as it prevents reprocessing of images that have already been handled. It's a simple yet effective.

# %%
import cv2
from PIL import Image
import numpy as np

def save_masks_to_drive(masks, save_path, image_name):
    if masks:  # Check if there is at least one mask
        try:
            img = Image.fromarray((masks[0] * 255).astype(np.uint8))  # Use only the first mask
            mask_file_path = os.path.join(save_path, f'mask_{image_name}_0.png')  # Name for the first mask
            img.save(mask_file_path)
            print(f"Successfully saved mask to drive: {mask_file_path}")
            return True
        except Exception as e:
            print(f"Failed saving mask to drive for {image_name}: {e}")
            return False

def process_images_in_batches(dataset_path, save_path, batch_size=100):
    processed_images_file = os.path.join(save_path, "processed_images.txt")
    if os.path.exists(processed_images_file):
        with open(processed_images_file, "r") as file:
            processed_images = set(file.read().splitlines())
    else:
        processed_images = set()

    image_paths = [os.path.join(dataset_path, f) for f in os.listdir(dataset_path) if os.path.isfile(os.path.join(dataset_path, f))]

    for i in range(0, len(image_paths), batch_size):
        batch_paths = image_paths[i:i+batch_size]
        for path in batch_paths:
            image_name = os.path.basename(path).replace('.jpg', '').replace('.png', '')
            if image_name in processed_images:
                print(f"Skipping already processed image: {path}")
                continue  # Skip this image because it has already been processed
                          # as generating masks for the whole dataset takes around 18h

            try:
                print(f"Processing: {path}")
                image_bgr = cv2.imread(path)
                image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)
t_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/192_20200724112811_1373_t.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/192_20200724112811_1408_t.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_192_20200724112811_1408_t_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/192_20200724112811_1408_t.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/192_20200724112811_1740_t.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_192_20200724112811_1740_t_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/192_20200724112811_1740_t.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/192_20200724112811_1386_t.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_192_20200724112811_1386_t_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/192_20200724112811_1386_t.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/192_20200724112811_1695_t.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_192_20200724112811_1695_t_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/192_20200724112811_1695_t.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/173_20200524004824_1328_t.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_173_20200524004824_1328_t_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/173_20200524004824_1328_t.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/192_20200715165926_1033_t.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_192_20200715165926_1033_t_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/192_20200715165926_1033_t.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/192_20200715165926_1044_t.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_192_20200715165926_1044_t_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/192_20200715165926_1044_t.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/192_20200715165926_1131_t.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_192_20200715165926_1131_t_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/192_20200715165926_1131_t.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/192_20200715165926_955_t.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_192_20200715165926_955_t_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/192_20200715165926_955_t.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/192_20200715165926_1025_t.jpg
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/diopsis_masks_generated/mask_192_20200715165926_1025_t_0.png
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean/192_20200715165926_1025_t.jpg
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean/192_20200715165926_1105_t.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-2a1b5272568b> in <cell line: 51>()
#      49
#      50
# ---> 51 process_images_in_batches(dataset_path, save_path, batch_size=100)
#
# <ipython-input-13-2a1b5272568b> in process_images_in_batches(dataset_path, save_path, batch_size)
#      38                 image_bgr = cv2.imread(path)
#      39                 image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)
# ---> 40                 sam_result = mask_generator.generate(image_rgb)
#      41                 masks = [mask['segmentation'] for mask in sorted(sam_result, key=lambda x: x['area'], reverse=True)]
#      42
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     113     def decorate_context(*args, **kwargs):
#     114         with ctx_factory():
# --> 115             return func(*args, **kwargs)
#     116
#     117     return decorate_context
#
# /usr/local/lib/python3.10/dist-packages/segment_anything/automatic_mask_generator.py in generate(self, image)
#     161
#     162         # Generate masks
# --> 163         mask_data = self._generate_masks(image)
#     164
#     165         # Filter small disconnected regions and holes in masks
#
# /usr/local/lib/python3.10/dist-packages/segment_anything/automatic_mask_generator.py in _generate_masks(self, image)
#     204         data = MaskData()
#     205         for crop_box, layer_idx in zip(crop_boxes, layer_idxs):
# --> 206             crop_data = self._process_crop(image, crop_box, layer_idx, orig_size)
#     207             data.cat(crop_data)
#     208
#
# /usr/local/lib/python3.10/dist-packages/segment_anything/automatic_mask_generator.py in _process_crop(self, image, crop_box, crop_layer_idx, orig_size)
#     234         cropped_im = image[y0:y1, x0:x1, :]
#     235         cropped_im_size = cropped_im.shape[:2]
# --> 236         self.predictor.set_image(cropped_im)
#     237
#     238         # Get points for this crop
#
# /usr/local/lib/python3.10/dist-packages/segment_anything/predictor.py in set_image(self, image, image_format)
#      58         input_image_torch = input_image_torch.permute(2, 0, 1).contiguous()[None, :, :, :]
#      59
# ---> 60         self.set_torch_image(input_image_torch, image.shape[:2])
#      61
#      62     @torch.no_grad()
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     113     def decorate_context(*args, **kwargs):
#     114         with ctx_factory():
# --> 115             return func(*args, **kwargs)
#     116
#     117     return decorate_context
#
# /usr/local/lib/python3.10/dist-packages/segment_anything/predictor.py in set_torch_image(self, transformed_image, original_image_size)
#      87         self.input_size = tuple(transformed_image.shape[-2:])
#      88         input_image = self.model.preprocess(transformed_image)
# ---> 89         self.features = self.model.image_encoder(input_image)
#      90         self.is_image_set = True
#      91
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
#    1513     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1518                 or _global_backward_pre_hooks or _global_backward_hooks
#    1519                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520             return forward_call(*args, **kwargs)
#    1521
#    1522         try:
#
# /usr/local/lib/python3.10/dist-packages/segment_anything/modeling/image_encoder.py in forward(self, x)
#     110
#     111         for blk in self.blocks:
# --> 112             x = blk(x)
#     113
#     114         x = self.neck(x.permute(0, 3, 1, 2))
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
#    1513     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1518                 or _global_backward_pre_hooks or _global_backward_hooks
#    1519                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520             return forward_call(*args, **kwargs)
#    1521
#    1522         try:
#
# /usr/local/lib/python3.10/dist-packages/segment_anything/modeling/image_encoder.py in forward(self, x)
#     172             x, pad_hw = window_partition(x, self.window_size)
#     173
# --> 174         x = self.attn(x)
#     175         # Reverse window partition
#     176         if self.window_size > 0:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
#    1513     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1518                 or _global_backward_pre_hooks or _global_backward_hooks
#    1519                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520             return forward_call(*args, **kwargs)
#    1521
#    1522         try:
#
# /usr/local/lib/python3.10/dist-packages/segment_anything/modeling/image_encoder.py in forward(self, x)
#     232
#     233         if self.use_rel_pos:
# --> 234             attn = add_decomposed_rel_pos(attn, q, self.rel_pos_h, self.rel_pos_w, (H, W), (H, W))
#     235
#     236         attn = attn.softmax(dim=-1)
#
# /usr/local/lib/python3.10/dist-packages/segment_anything/modeling/image_encoder.py in add_decomposed_rel_pos(attn, q, rel_pos_h, rel_pos_w, q_size, k_size)
#     347     q_h, q_w = q_size
#     348     k_h, k_w = k_size
# --> 349     Rh = get_rel_pos(q_h, k_h, rel_pos_h)
#     350     Rw = get_rel_pos(q_w, k_w, rel_pos_w)
#     351
#
# KeyboardInterrupt:

# %% [markdown]
# ## Checking if the number of images in the dataset match the number of processed images

# %%
num_images = len(os.listdir(dataset_path))
print(f"Number of images read in dataset: {num_images}")

# ------------------------------------------------------

num_images = len(os.listdir(save_path))
print(f"Number of images read in processed images: {num_images}")
# Out:
# Number of images read in dataset: 27649
# Number of images read in processed images: 25617
