# %% [markdown]
# <a href="https://colab.research.google.com/github/martintmv-git/RB-IBDM/blob/main/Experiments/Generating%20Masks%20with%20SAM/TIFF%20masks%20generation/tiff_clean_dataset_generate_masks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Generating object masks with `segment-anything` for RB-IBDM

# %% [markdown]
# ## Before starting
#
# Make sure you are connected to a GPU.

# %%
# !nvidia-smi
# Out:
# Tue Apr  2 10:41:21 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   65C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# **NOTE:** To make it easier for us to manage datasets, images and models we create a `HOME` constant.

# %%
import os
HOME = os.getcwd()
print("HOME:", HOME)
# Out:
# HOME: /content

# %% [markdown]
# # Install Segment Anything Model (SAM) and dependencies

# %%
# !pip install -q 'git+https://github.com/facebookresearch/segment-anything.git'
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for segment-anything (setup.py) ... done

# %% [markdown]
# # Download SAM weights

# %%
# !mkdir -p {HOME}/weights
# !wget -q https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth -P {HOME}/weights

# %%
import os

CHECKPOINT_PATH = os.path.join(HOME, "weights", "sam_vit_h_4b8939.pth")
print(CHECKPOINT_PATH, "; exist:", os.path.isfile(CHECKPOINT_PATH))
# Out:
# /content/weights/sam_vit_h_4b8939.pth ; exist: True

# %% [markdown]
# # Download Insect Data

# %%
# !mkdir -p {HOME}/data

import os
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Dataset of images
dataset_path = '/content/drive/MyDrive/diopsis_tests/images_clean_tiff'

# Where the generated masks will be saved
save_path = '/content/drive/MyDrive/diopsis_tests/tiff_masks_generated'

# Ensure the directory exists
if not os.path.exists(save_path):
    os.makedirs(save_path)
    print(f"Directory created for saving masks: {save_path}")
else:
    print(f"Save directory already exists: {save_path}")

# Counting the number of images in the dataset
num_images = len(os.listdir(dataset_path))
print(f"Number of images read in dataset: {num_images}")
# Out:
# Directory created for saving masks: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated
# Number of images read in dataset: 266

# %% [markdown]
# # Load Model

# %%
import torch

DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
MODEL_TYPE = "vit_h"

# %%
from segment_anything import sam_model_registry, SamAutomaticMaskGenerator, SamPredictor

sam = sam_model_registry[MODEL_TYPE](checkpoint=CHECKPOINT_PATH).to(device=DEVICE)

# %% [markdown]
# # Automated Mask Generation
#
# To run automatic mask generation, provide a SAM model to the `SamAutomaticMaskGenerator` class. Set the path below to the SAM checkpoint. Running on CUDA and with the default model is recommended.

# %%
mask_generator = SamAutomaticMaskGenerator(sam)

# %% [markdown]
# ### Generate masks with SAM
#
# Creating `processed_images.txt` so if I need to re-run the script after quitting, it will first read the `processed_images.txt` file to determine which images have already been processed.
#
# This approach saves a lot of time and computational resources, especially when working with large datasets or when running processes that have a long execution time, as it prevents reprocessing of images that have already been handled. It's a simple yet effective.

# %%
import cv2
from PIL import Image
import numpy as np

def save_masks_to_drive(masks, save_path, image_name):
    if masks:  # Check if there is at least one mask
        try:
            img = Image.fromarray((masks[0] * 255).astype(np.uint8))  # Use only the first mask
            mask_file_path = os.path.join(save_path, f'mask_{image_name}_0.tiff')  # Name for the first mask with .tiff extension
            img.save(mask_file_path)
            print(f"Successfully saved mask to drive: {mask_file_path}")
            return True
        except Exception as e:
            print(f"Failed saving mask to drive for {image_name}: {e}")
            return False

def process_images_in_batches(dataset_path, save_path, batch_size=100):
    processed_images_file = os.path.join(save_path, "processed_img.txt")
    if os.path.exists(processed_images_file):
        with open(processed_images_file, "r") as file:
            processed_images = set(file.read().splitlines())
    else:
        processed_images = set()

    image_paths = [os.path.join(dataset_path, f) for f in os.listdir(dataset_path) if os.path.isfile(os.path.join(dataset_path, f))]

    for i in range(0, len(image_paths), batch_size):
        batch_paths = image_paths[i:i+batch_size]
        for path in batch_paths:
            image_name = os.path.basename(path).replace('.jpg', '').replace('.png', '')
            if image_name in processed_images:
                print(f"Skipping already processed image: {path}")
                continue  # Skip this image because it has already been processed
                          # as generating masks for the whole dataset takes around 18h

            try:
                print(f"Processing: {path}")
                image_bgr = cv2.imread(path)
                image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)
                sam_result = mask_generator.generate(image_rgb)
                masks = [mask['segmentation'] for mask in sorted(sam_result, key=lambda x: x['area'], reverse=True)]

                if save_masks_to_drive(masks, save_path, image_name):
                    with open(processed_images_file, "a") as file:
                        file.write(f"{image_name}\n")
                    print(f"Successfully processed and saved masks for: {path}")
            except Exception as e:
                print(f"Error processing {path}: {e}")

process_images_in_batches(dataset_path, save_path, batch_size=100)
# Out:
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/222.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_222.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/222.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/56.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_56.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/56.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/46.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_46.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/46.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/209.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_209.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/209.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/206.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_206.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/206.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/50.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_50.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/50.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/249.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_249.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/249.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/215.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_215.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/215.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/190.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_190.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/190.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/147.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_147.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/147.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/63.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_63.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/63.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/24.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_24.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/24.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/175.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_175.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/175.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/111.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_111.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/111.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/148.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_148.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/148.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/125.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_125.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/125.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/207.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_207.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/207.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/44.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_44.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/44.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/220.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_220.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/220.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/248.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_248.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/248.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/69.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_69.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/69.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/259.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_259.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/259.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/133.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_133.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/133.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/197.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_197.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/197.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/114.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_114.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/114.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/155.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_155.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/155.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/58.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_58.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/58.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/167.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_167.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/167.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/232.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_232.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/232.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/229.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_229.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/229.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/108.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_108.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/108.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/138.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_138.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/138.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/237.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_237.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/237.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/226.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_226.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/226.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/194.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_194.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/194.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/145.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_145.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/145.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/110.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_110.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/110.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/203.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_203.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/203.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/246.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_246.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/246.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/162.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_162.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/162.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/260.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_260.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/260.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/25.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_25.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/25.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/182.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_182.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/182.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/217.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_217.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/217.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/21.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_21.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/21.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/115.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_115.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/115.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/53.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_53.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/53.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/106.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_106.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/106.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/88.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_88.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/88.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/100.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_100.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/100.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/239.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_239.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/239.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/218.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_218.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/218.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/265.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_265.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/265.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/140.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_140.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/140.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/15.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_15.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/15.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/253.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_253.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/253.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/30.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_30.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/30.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/78.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_78.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/78.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/137.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_137.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/137.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/233.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_233.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/233.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/136.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_136.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/136.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/33.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_33.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/33.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/7.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_7.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/7.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/83.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_83.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/83.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/144.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_144.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/144.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/73.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_73.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/73.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/225.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_225.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/225.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/266.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_266.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/266.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/84.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_84.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/84.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/129.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_129.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/129.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/4.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_4.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/4.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/57.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_57.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/57.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/87.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_87.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/87.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/134.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_134.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/134.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/55.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_55.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/55.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/102.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_102.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/102.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/93.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_93.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/93.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/171.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_171.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/171.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/152.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_152.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/152.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/60.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_60.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/60.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/23.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_23.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/23.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/40.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_40.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/40.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/166.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_166.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/166.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/184.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_184.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/184.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/10.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_10.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/10.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/178.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_178.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/178.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/86.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_86.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/86.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/91.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_91.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/91.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/183.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_183.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/183.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/18.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_18.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/18.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/210.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_210.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/210.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/228.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_228.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/228.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/143.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_143.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/143.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/20.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_20.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/20.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/192.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_192.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/192.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/95.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_95.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/95.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/254.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_254.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/254.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/151.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_151.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/151.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/68.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_68.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/68.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/235.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_235.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/235.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/3.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_3.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/3.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/42.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_42.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/42.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/105.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_105.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/105.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/65.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_65.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/65.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/257.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_257.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/257.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/230.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_230.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/230.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/22.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_22.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/22.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/198.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_198.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/198.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/85.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_85.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/85.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/205.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_205.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/205.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/238.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_238.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/238.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/193.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_193.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/193.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/13.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_13.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/13.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/181.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_181.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/181.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/189.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_189.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/189.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/156.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_156.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/156.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/94.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_94.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/94.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/132.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_132.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/132.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/135.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_135.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/135.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/49.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_49.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/49.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/177.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_177.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/177.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/231.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_231.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/231.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/61.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_61.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/61.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/11.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_11.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/11.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/214.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_214.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/214.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/250.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_250.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/250.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/124.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_124.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/124.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/98.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_98.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/98.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/103.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_103.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/103.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/234.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_234.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/234.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/8.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_8.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/8.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/191.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_191.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/191.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/28.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_28.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/28.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/75.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_75.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/75.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/6.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_6.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/6.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/16.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_16.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/16.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/179.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_179.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/179.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/196.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_196.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/196.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/208.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_208.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/208.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/256.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_256.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/256.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/185.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_185.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/185.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/66.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_66.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/66.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/242.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_242.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/242.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/200.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_200.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/200.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/224.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_224.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/224.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/187.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_187.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/187.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/130.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_130.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/130.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/120.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_120.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/120.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/47.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_47.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/47.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/262.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_262.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/262.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/79.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_79.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/79.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/38.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_38.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/38.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/19.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_19.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/19.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/119.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_119.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/119.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/51.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_51.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/51.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/36.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_36.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/36.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/52.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_52.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/52.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/180.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_180.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/180.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/14.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_14.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/14.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/149.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_149.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/149.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/70.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_70.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/70.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/201.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_201.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/201.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/123.tiff
# ...
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/117.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_117.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/117.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/169.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_169.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/169.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/236.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_236.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/236.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/199.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_199.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/199.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/127.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_127.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/127.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/172.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_172.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/172.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/212.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_212.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/212.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/251.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_251.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/251.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/131.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_131.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/131.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/241.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_241.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/241.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/121.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_121.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/121.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/219.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_219.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/219.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/109.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_109.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/109.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/97.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_97.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/97.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/255.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_255.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/255.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/96.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_96.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/96.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/202.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_202.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/202.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/89.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_89.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/89.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/12.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_12.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/12.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/1.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_1.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/1.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/77.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_77.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/77.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/32.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_32.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/32.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/170.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_170.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/170.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/54.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_54.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/54.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/223.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_223.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/223.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/160.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_160.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/160.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/99.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_99.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/99.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/113.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_113.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/113.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/128.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_128.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/128.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/9.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_9.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/9.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/157.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_157.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/157.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/122.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_122.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/122.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/150.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_150.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/150.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/263.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_263.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/263.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/154.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_154.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/154.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/74.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_74.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/74.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/37.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_37.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/37.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/41.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_41.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/41.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/139.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_139.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/139.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/107.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_107.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/107.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/204.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_204.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/204.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/163.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_163.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/163.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/176.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_176.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/176.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/258.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_258.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/258.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/81.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_81.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/81.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/59.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_59.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/59.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/146.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_146.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/146.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/142.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_142.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/142.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/29.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_29.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/29.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/48.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_48.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/48.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/195.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_195.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/195.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/17.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_17.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/17.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/26.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_26.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/26.tiff
# Processing: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/264.tiff
# Successfully saved mask to drive: /content/drive/MyDrive/diopsis_tests/tiff_masks_generated/mask_264.tiff_0.tiff
# Successfully processed and saved masks for: /content/drive/MyDrive/diopsis_tests/images_clean_tiff/264.tiff

# %% [markdown]
# ## Checking if the number of images in the dataset match the number of processed images

# %%
num_images = len(os.listdir(dataset_path))
print(f"Number of images read in dataset: {num_images}")

# ------------------------------------------------------

num_images = len(os.listdir(save_path))
print(f"Number of images read in processed images: {num_images}")
# Out:
# Number of images read in dataset: 266
# Number of images read in processed images: 266
