# %% [markdown]
# <a href="https://colab.research.google.com/github/martintmv-git/RB-IBDM/blob/main/Experiments/Generating%20Masks%20with%20SAM/sam_floral_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Segment Anything by Meta AI
# ### Generating object masks with SAM for RB-IBDM and saving them in Google Drive

# %% [markdown]
# ## Before starting
#
# Make sure you are connected to a GPU.

# %%
# !nvidia-smi
# Out:
# Mon Mar 25 19:03:31 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# **NOTE:** To make it easier for us to manage datasets, images and models we create a `HOME` constant.

# %%
import os
HOME = os.getcwd()
print("HOME:", HOME)
# Out:
# HOME: /content

# %% [markdown]
# ## Install Segment Anything Model (SAM) and dependencies

# %%
# !pip install -q 'git+https://github.com/facebookresearch/segment-anything.git'
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for segment-anything (setup.py) ... done

# %% [markdown]
# ### Download SAM weights

# %%
# !mkdir -p {HOME}/weights
# !wget -q https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth -P {HOME}/weights

# %%
import os

CHECKPOINT_PATH = os.path.join(HOME, "weights", "sam_vit_h_4b8939.pth")
print(CHECKPOINT_PATH, "; exist:", os.path.isfile(CHECKPOINT_PATH))
# Out:
# /content/weights/sam_vit_h_4b8939.pth ; exist: True

# %% [markdown]
# ## Download Insect Data

# %%
# !mkdir -p {HOME}/data

# !wget -q 'link-to-img' -P {HOME}/data

# %% [markdown]
# ## Load Model

# %%
import torch

DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
MODEL_TYPE = "vit_h"

# %%
from segment_anything import sam_model_registry, SamAutomaticMaskGenerator, SamPredictor

sam = sam_model_registry[MODEL_TYPE](checkpoint=CHECKPOINT_PATH).to(device=DEVICE)

# %% [markdown]
# ## Automated Mask Generation
#
# To run automatic mask generation, provide a SAM model to the `SamAutomaticMaskGenerator` class. Set the path below to the SAM checkpoint. Running on CUDA and with the default model is recommended.

# %%
mask_generator = SamAutomaticMaskGenerator(sam)

# %%
import os

IMAGE_NAME = "/content/flower-day-1.jpeg"
IMAGE_PATH = os.path.join(HOME, "data", IMAGE_NAME)

# %% [markdown]
# ### Generate masks with SAM

# %%
import cv2
import supervision as sv

image_bgr = cv2.imread(IMAGE_PATH)
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

sam_result = mask_generator.generate(image_rgb)

# %% [markdown]
# ### Output format

# %% [markdown]
# `SamAutomaticMaskGenerator` returns a `list` of masks, where each mask is a `dict` containing various information about the mask:
#
# * `segmentation` - `[np.ndarray]` - the mask with `(W, H)` shape, and `bool` type
# * `area` - `[int]` - the area of the mask in pixels
# * `bbox` - `[List[int]]` - the boundary box of the mask in `xywh` format
# * `predicted_iou` - `[float]` - the model's own prediction for the quality of the mask
# * `point_coords` - `[List[List[float]]]` - the sampled input point that generated this mask
# * `stability_score` - `[float]` - an additional measure of mask quality
# * `crop_box` - `List[int]` - the crop of the image used to generate this mask in `xywh` format

# %%
print(sam_result[0].keys())
# Out:
# dict_keys(['segmentation', 'area', 'bbox', 'predicted_iou', 'point_coords', 'stability_score', 'crop_box'])

# %% [markdown]
# ### Results visualisation with Supervision
#
# As of version `0.5.0` Supervision has native support for SAM.

# %%
mask_annotator = sv.MaskAnnotator(color_lookup=sv.ColorLookup.INDEX)

detections = sv.Detections.from_sam(sam_result=sam_result)

annotated_image = mask_annotator.annotate(scene=image_bgr.copy(), detections=detections)

sv.plot_images_grid(
    images=[image_bgr, annotated_image],
    grid_size=(1, 2),
    titles=['source image', 'segmented image']
)

# %% [markdown]
# ### Interaction with segmentation results

# %%
import math

masks = [
    mask['segmentation']
    for mask
    in sorted(sam_result, key=lambda x: x['area'], reverse=True)
]

# Calculate the number of rows needed, rounding up to ensure enough space
num_rows = math.ceil(len(masks) / 8)

sv.plot_images_grid(
    images=masks,
    grid_size=(8, num_rows),  # use num_rows here
    size=(16, 16)
)

# %% [markdown]
# ### Save mask results to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
import os

# Path to save my masks
folder_path = '/content/drive/My Drive/diopsis_masks/floral_dataset'
if not os.path.exists(folder_path):
    os.makedirs(folder_path)
    print(f"Folder '{folder_path}' created")
else:
    print(f"Folder '{folder_path}' already exists")
# Out:
# Mounted at /content/drive
# Folder '/content/drive/My Drive/diopsis_masks/floral_dataset' created

# %%
from PIL import Image
import numpy as np

def save_masks_to_drive(masks, folder_path):
    for i, mask in enumerate(masks):
        # Masks are numpy arrays so convert them to PIL images
        img = Image.fromarray((mask * 255).astype(np.uint8))

        file_path = os.path.join(folder_path, f'mask_{i}.png')
        img.save(file_path)
        print(f'Saved: {file_path}')

save_masks_to_drive(masks, folder_path)
# Out:
# Saved: /content/drive/My Drive/diopsis_masks/floral_dataset/mask_0.png
# Saved: /content/drive/My Drive/diopsis_masks/floral_dataset/mask_1.png
# Saved: /content/drive/My Drive/diopsis_masks/floral_dataset/mask_2.png
# Saved: /content/drive/My Drive/diopsis_masks/floral_dataset/mask_3.png
# Saved: /content/drive/My Drive/diopsis_masks/floral_dataset/mask_4.png
# Saved: /content/drive/My Drive/diopsis_masks/floral_dataset/mask_5.png
# Saved: /content/drive/My Drive/diopsis_masks/floral_dataset/mask_6.png
# Saved: /content/drive/My Drive/diopsis_masks/floral_dataset/mask_7.png
# Saved: /content/drive/My Drive/diopsis_masks/floral_dataset/mask_8.png
# Saved: /content/drive/My Drive/diopsis_masks/floral_dataset/mask_9.png
# Saved: /content/drive/My Drive/diopsis_masks/floral_dataset/mask_10.png
# Saved: /content/drive/My Drive/diopsis_masks/floral_dataset/mask_11.png
# Saved: /content/drive/My Drive/diopsis_masks/floral_dataset/mask_12.png
# Saved: /content/drive/My Drive/diopsis_masks/floral_dataset/mask_13.png
# Saved: /content/drive/My Drive/diopsis_masks/floral_dataset/mask_14.png
# Saved: /content/drive/My Drive/diopsis_masks/floral_dataset/mask_15.png
# Saved: /content/drive/My Drive/diopsis_masks/floral_dataset/mask_16.png
# Saved: /content/drive/My Drive/diopsis_masks/floral_dataset/mask_17.png
# Saved: /content/drive/My Drive/diopsis_masks/floral_dataset/mask_18.png
# Saved: /content/drive/My Drive/diopsis_masks/floral_dataset/mask_19.png
# Saved: /content/drive/My Drive/diopsis_masks/floral_dataset/mask_20.png
# Saved: /content/drive/My Drive/diopsis_masks/floral_dataset/mask_21.png
# Saved: /content/drive/My Drive/diopsis_masks/floral_dataset/mask_22.png
# Saved: /content/drive/My Drive/diopsis_masks/floral_dataset/mask_23.png
# Saved: /content/drive/My Drive/diopsis_masks/floral_dataset/mask_24.png
# Saved: /content/drive/My Drive/diopsis_masks/floral_dataset/mask_25.png
# Saved: /content/drive/My Drive/diopsis_masks/floral_dataset/mask_26.png
# Saved: /content/drive/My Drive/diopsis_masks/floral_dataset/mask_27.png
# Saved: /content/drive/My Drive/diopsis_masks/floral_dataset/mask_28.png
# Saved: /content/drive/My Drive/diopsis_masks/floral_dataset/mask_29.png
# Saved: /content/drive/My Drive/diopsis_masks/floral_dataset/mask_30.png
# Saved: /content/drive/My Drive/diopsis_masks/floral_dataset/mask_31.png
# Saved: /content/drive/My Drive/diopsis_masks/floral_dataset/mask_32.png
# Saved: /content/drive/My Drive/diopsis_masks/floral_dataset/mask_33.png
# Saved: /content/drive/My Drive/diopsis_masks/floral_dataset/mask_34.png
# Saved: /content/drive/My Drive/diopsis_masks/floral_dataset/mask_35.png
# Saved: /content/drive/My Drive/diopsis_masks/floral_dataset/mask_36.png
