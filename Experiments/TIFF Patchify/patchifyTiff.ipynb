# %%
from tifffile import imread, TiffFile
import patchify
from PIL import Image

# %%
import cv2 as cv

# %%
with TiffFile('data/img_source.tif') as tif:
   for page in tif.pages:
      image = page.asarray()

# %%
tif[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 tif[0]
#
# TypeError: 'TiffFile' object is not subscriptable

# %%
image[0]
# Out:
# array([[236, 162,  31],
#        [242, 168,  37],
#        [243, 169,  38],
#        ...,
#        [220, 143,  29],
#        [222, 145,  31],
#        [224, 147,  33]], dtype=uint8)

# %%
imagef = imread('data/img_source.tif', key=0)

# %%
imagef
# Out:
# array([[[234, 160,  27],
#         [235, 161,  28],
#         [236, 162,  29],
#         ...,
#         [237, 166,  24],
#         [239, 168,  26],
#         [241, 170,  28]],
#
#        [[232, 158,  25],
#         [233, 159,  26],
#         [234, 160,  27],
#         ...,
#         [235, 164,  22],
#         [230, 159,  17],
#         [230, 159,  17]],
#
#        [[230, 156,  23],
#         [231, 157,  24],
#         [232, 158,  25],
#         ...,
#         [244, 173,  31],
#         [232, 161,  19],
#         [230, 159,  17]],
#
#        ...,
#
#        [[221, 146,  19],
#         [222, 147,  20],
#         [223, 148,  21],
#         ...,
#         [235, 157,  31],
#         [234, 156,  30],
#         [233, 155,  29]],
#
#        [[222, 147,  20],
#         [225, 150,  23],
#         [229, 154,  27],
#         ...,
#         [239, 161,  35],
#         [239, 161,  35],
#         [238, 160,  34]],
#
#        [[220, 145,  18],
#         [224, 149,  22],
#         [228, 153,  26],
# ...

# %%
all = cv.imread('data/img_source.tif', +1)

# %%
all[0].shape
# Out:
# (263, 3)

# %%
imgtry = Image.fromarray(imagef)

# %%
imgtry
# Out:
# <PIL.Image.Image image mode=RGB size=263x285>

# %%
tiffImages = imread('data/img_source.tif')

# %%
tiffImages
# Out:
# array([[[234, 160,  27],
#         [235, 161,  28],
#         [236, 162,  29],
#         ...,
#         [237, 166,  24],
#         [239, 168,  26],
#         [241, 170,  28]],
#
#        [[232, 158,  25],
#         [233, 159,  26],
#         [234, 160,  27],
#         ...,
#         [235, 164,  22],
#         [230, 159,  17],
#         [230, 159,  17]],
#
#        [[230, 156,  23],
#         [231, 157,  24],
#         [232, 158,  25],
#         ...,
#         [244, 173,  31],
#         [232, 161,  19],
#         [230, 159,  17]],
#
#        ...,
#
#        [[221, 146,  19],
#         [222, 147,  20],
#         [223, 148,  21],
#         ...,
#         [235, 157,  31],
#         [234, 156,  30],
#         [233, 155,  29]],
#
#        [[222, 147,  20],
#         [225, 150,  23],
#         [229, 154,  27],
#         ...,
#         [239, 161,  35],
#         [239, 161,  35],
#         [238, 160,  34]],
#
#        [[220, 145,  18],
#         [224, 149,  22],
#         [228, 153,  26],
# ...

# %%
img = Image.fromarray(tiffImages[0])

# %%
tiffImages.shape
# Out:
# (285, 263, 3)

# %%
img.show()
